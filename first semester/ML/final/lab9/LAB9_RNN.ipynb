# %% [markdown]
# ## ข้อ 1.

# %%
import pandas as pd
import numpy as np

url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/monthly-sunspots.csv"
df = pd.read_csv(url)

data = df.values

print(len(data))
# Out:
# 2820

# %% [markdown]
# ## ข้อ 2.

# %%
data
# Out:
# array([['1749-01', 58.0],
#        ['1749-02', 62.6],
#        ['1749-03', 70.0],
#        ...,
#        ['1983-10', 55.8],
#        ['1983-11', 33.3],
#        ['1983-12', 33.4]], dtype=object)

# %%
import matplotlib.pyplot as plt

#### Plot graph
plt.figure(figsize=(15, 6), dpi=80)
plt.plot(df['Sunspots'])

# %% [markdown]
# ## ข้อ 3.

# %%
df=df.drop(columns=['Month'])
df
# Out:
#       Sunspots
# 0         58.0
# 1         62.6
# 2         70.0
# 3         55.7
# 4         85.0
# ...        ...
# 2815      71.8
# 2816      50.3
# 2817      55.8
# 2818      33.3
# 2819      33.4
#
# [2820 rows x 1 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))
df = scaler.fit_transform(df.values.reshape(-1, 1))
df
# Out:
# array([[0.2285264 ],
#        [0.24665091],
#        [0.27580772],
#        ...,
#        [0.21985816],
#        [0.13120567],
#        [0.13159968]])

# %%
n=int(len(df)*0.8)
n
# Out:
# 2256

# %%
train_data=df[:n]
test_data=df[n:]
train_data.shape
# Out:
# (2256, 1)

# %%
test_data.shape
# Out:
# (564, 1)

# %% [markdown]
# ## ข้อ 4.

# %%
def GenXY(dat, timstep):
  X, Y = [], []
  for i in range(len(dat) - time_steps):
    X.append(dat[i : i + time_steps])
    Y.append(dat[i + time_steps])
  X = np.array(X)
  Y = np.array(Y)
  return X,Y

time_steps = 12
trainX, trainY = GenXY(train_data, time_steps)
testX, testY = GenXY(test_data, time_steps)

# %%
trainX.shape
# Out:
# (2244, 12, 1)

# %%
trainY.shape
# Out:
# (2244, 1)

# %%
testX.shape
# Out:
# (552, 12, 1)

# %%
testY.shape
# Out:
# (552, 1)

# %% [markdown]
# ## ข้อ 5.

# %%
from tensorflow.keras.layers import Input, SimpleRNN, Dense
from tensorflow.keras.models import Sequential
model = Sequential([
  Input(shape=(time_steps, 1)),
  SimpleRNN(32, activation = 'tanh'),
  Dense(1, activation = 'sigmoid')
  ])

model.summary()
model.compile(loss='mean_squared_error', optimizer='adam')
hist = model.fit(trainX, trainY, epochs=50, validation_split = 0.1)
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 32)             │         1,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,121 (4.38 KB)
#  Trainable params: 1,121 (4.38 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.0525 - val_loss: 0.0111
# Epoch 2/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0118 - val_loss: 0.0047
# Epoch 3/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0059 - val_loss: 0.0045
# Epoch 4/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0050 - val_loss: 0.0041
# Epoch 5/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0047 - val_loss: 0.0043
# Epoch 6/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0045 - val_loss: 0.0038
# Epoch 7/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0043 - val_loss: 0.0037
# Epoch 8/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0049 - val_loss: 0.0039
# Epoch 9/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0044 - val_loss: 0.0045
# Epoch 10/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0043 - val_loss: 0.0036
# Epoch 11/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0042 - val_loss: 0.0040
# Epoch 12/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0042 - val_loss: 0.0038
# Epoch 13/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0041 - val_loss: 0.0034
# Epoch 14/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0044 - val_loss: 0.0037
# Epoch 15/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0043 - val_loss: 0.0038
# Epoch 16/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0040 - val_loss: 0.0034
# Epoch 17/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0047 - val_loss: 0.0033
# Epoch 18/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0040 - val_loss: 0.0044
# Epoch 19/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0047 - val_loss: 0.0032
# Epoch 20/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0040 - val_loss: 0.0032
# Epoch 21/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0039 - val_loss: 0.0039
# Epoch 22/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0040 - val_loss: 0.0032
# Epoch 23/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0040 - val_loss: 0.0033
# Epoch 24/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0041 - val_loss: 0.0032
# Epoch 25/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0038 - val_loss: 0.0031
# Epoch 26/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0037 - val_loss: 0.0032
# Epoch 27/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0037 - val_loss: 0.0031
# Epoch 28/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0038 - val_loss: 0.0031
# Epoch 29/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0041 - val_loss: 0.0031
# Epoch 30/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0039 - val_loss: 0.0032
# Epoch 31/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0038 - val_loss: 0.0030
# Epoch 32/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0037 - val_loss: 0.0032
# Epoch 33/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0036 - val_loss: 0.0031
# Epoch 34/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0037 - val_loss: 0.0040
# Epoch 35/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0036 - val_loss: 0.0030
# Epoch 36/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0039 - val_loss: 0.0030
# Epoch 37/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0039 - val_loss: 0.0032
# Epoch 38/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0038 - val_loss: 0.0034
# Epoch 39/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0038 - val_loss: 0.0030
# Epoch 40/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0035 - val_loss: 0.0030
# Epoch 41/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0034 - val_loss: 0.0029
# Epoch 42/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0037 - val_loss: 0.0029
# Epoch 43/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0037 - val_loss: 0.0031
# Epoch 44/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0037 - val_loss: 0.0029
# Epoch 45/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0035 - val_loss: 0.0030
# Epoch 46/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0035 - val_loss: 0.0029
# Epoch 47/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0038 - val_loss: 0.0029
# Epoch 48/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0037 - val_loss: 0.0030
# Epoch 49/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0038 - val_loss: 0.0029
# Epoch 50/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0038 - val_loss: 0.0033

# %% [markdown]
# ## ข้อ 6.

# %%
from sklearn.metrics import mean_squared_error

test_predict = model.predict(testX)


test_rmse = mean_squared_error(testY, test_predict)

print('Test RMSE: %.3f RMSE' % (test_rmse))
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# Test RMSE: 0.007 RMSE

# %% [markdown]
# ## ข้อ 7.

# %%
from tensorflow.keras.layers import GRU

# %%
model = Sequential([
  Input(shape=(time_steps, 1)),
  GRU(32, activation = 'tanh'),
  Dense(1, activation = 'sigmoid')
  ])

model.summary()
model.compile(loss='mean_squared_error', optimizer='adam')
hist = model.fit(trainX, trainY, epochs=50, validation_split = 0.1)
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru (GRU)                       │ (None, 32)             │         3,360 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,393 (13.25 KB)
#  Trainable params: 3,393 (13.25 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0952 - val_loss: 0.0159
# Epoch 2/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0200 - val_loss: 0.0049
# Epoch 3/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0057 - val_loss: 0.0054
# Epoch 4/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0057 - val_loss: 0.0047
# Epoch 5/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0054 - val_loss: 0.0045
# Epoch 6/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0053 - val_loss: 0.0044
# Epoch 7/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0048 - val_loss: 0.0041
# Epoch 8/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0048 - val_loss: 0.0041
# Epoch 9/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0050 - val_loss: 0.0040
# Epoch 10/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0045 - val_loss: 0.0038
# Epoch 11/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0044 - val_loss: 0.0038
# Epoch 12/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0041 - val_loss: 0.0036
# Epoch 13/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0042 - val_loss: 0.0036
# Epoch 14/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0043 - val_loss: 0.0035
# Epoch 15/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0041 - val_loss: 0.0035
# Epoch 16/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0040 - val_loss: 0.0034
# Epoch 17/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0041 - val_loss: 0.0033
# Epoch 18/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0040 - val_loss: 0.0033
# Epoch 19/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0036 - val_loss: 0.0032
# Epoch 20/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0037 - val_loss: 0.0032
# Epoch 21/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0037 - val_loss: 0.0032
# Epoch 22/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0040 - val_loss: 0.0033
# Epoch 23/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0040 - val_loss: 0.0031
# Epoch 24/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0037 - val_loss: 0.0031
# Epoch 25/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0038 - val_loss: 0.0031
# Epoch 26/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0039 - val_loss: 0.0031
# Epoch 27/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0036 - val_loss: 0.0032
# Epoch 28/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0041 - val_loss: 0.0030
# Epoch 29/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0036 - val_loss: 0.0035
# Epoch 30/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0037 - val_loss: 0.0031
# Epoch 31/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0039 - val_loss: 0.0032
# Epoch 32/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0037 - val_loss: 0.0030
# Epoch 33/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0037 - val_loss: 0.0030
# Epoch 34/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0035 - val_loss: 0.0030
# Epoch 35/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0037 - val_loss: 0.0031
# Epoch 36/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0040 - val_loss: 0.0029
# Epoch 37/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0034 - val_loss: 0.0030
# Epoch 38/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0035 - val_loss: 0.0031
# Epoch 39/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0040 - val_loss: 0.0029
# Epoch 40/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0037 - val_loss: 0.0030
# Epoch 41/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0037 - val_loss: 0.0030
# Epoch 42/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0035 - val_loss: 0.0029
# Epoch 43/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0039 - val_loss: 0.0029
# Epoch 44/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0034 - val_loss: 0.0030
# Epoch 45/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0038 - val_loss: 0.0029
# Epoch 46/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0037 - val_loss: 0.0029
# Epoch 47/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0035 - val_loss: 0.0029
# Epoch 48/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0034 - val_loss: 0.0029
# Epoch 49/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0037 - val_loss: 0.0031
# Epoch 50/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0032 - val_loss: 0.0029

# %%
from sklearn.metrics import mean_squared_error

test_predict = model.predict(testX)


test_rmse = mean_squared_error(testY, test_predict)

print('Test RMSE: %.3f RMSE' % (test_rmse))
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step
# Test RMSE: 0.006 RMSE

# %% [markdown]
# ## ข้อ 8.

# %%
def GenXY(dat, timstep):
  X, Y = [], []
  for i in range(len(dat) - time_steps - output_length + 1):
    X.append(dat[i : i + time_steps])
    Y.append(dat[i+ time_steps : i + time_steps +output_length])
  X = np.array(X)
  Y = np.array(Y)
  return X,Y

time_steps = 5
output_length = 3
trainX, trainY = GenXY(train_data, time_steps)
testX, testY = GenXY(test_data, time_steps)

# %%
trainX.shape
# Out:
# (2249, 5, 1)

# %%
trainY.shape
# Out:
# (2249, 3, 1)

# %%
testX.shape
# Out:
# (557, 5, 1)

# %%
testY.shape
# Out:
# (557, 3, 1)

# %% [markdown]
# ## ข้อ 9.

# %%
from tensorflow.keras.layers import Input, LSTM, Dense
model = Sequential([
  Input(shape=(time_steps, 1)),
  LSTM(64, activation = 'tanh'),
  Dense(output_length, activation = 'sigmoid')
])
model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(trainX, trainY, epochs=100, validation_split = 0.1)
# Out:
# Epoch 1/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0962 - val_loss: 0.0169
# Epoch 2/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0271 - val_loss: 0.0078
# Epoch 3/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0091 - val_loss: 0.0053
# Epoch 4/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0062 - val_loss: 0.0051
# Epoch 5/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0059 - val_loss: 0.0055
# Epoch 6/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0062 - val_loss: 0.0051
# Epoch 7/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0059 - val_loss: 0.0049
# Epoch 8/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0059 - val_loss: 0.0049
# Epoch 9/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0055 - val_loss: 0.0049
# Epoch 10/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0059 - val_loss: 0.0047
# Epoch 11/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0052 - val_loss: 0.0050
# Epoch 12/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0056 - val_loss: 0.0050
# Epoch 13/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0054 - val_loss: 0.0048
# Epoch 14/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0056 - val_loss: 0.0050
# Epoch 15/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0049 - val_loss: 0.0048
# Epoch 16/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0052 - val_loss: 0.0047
# Epoch 17/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0055 - val_loss: 0.0044
# Epoch 18/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0055 - val_loss: 0.0045
# Epoch 19/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0054 - val_loss: 0.0045
# Epoch 20/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0054 - val_loss: 0.0045
# Epoch 21/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0053 - val_loss: 0.0043
# Epoch 22/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0050 - val_loss: 0.0044
# Epoch 23/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.0050 - val_loss: 0.0044
# Epoch 24/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0054 - val_loss: 0.0043
# Epoch 25/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0050 - val_loss: 0.0043
# Epoch 26/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0050 - val_loss: 0.0044
# Epoch 27/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0049 - val_loss: 0.0043
# Epoch 28/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0052 - val_loss: 0.0042
# Epoch 29/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0045 - val_loss: 0.0041
# Epoch 30/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0049 - val_loss: 0.0042
# Epoch 31/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0047 - val_loss: 0.0041
# Epoch 32/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0046 - val_loss: 0.0041
# Epoch 33/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0047 - val_loss: 0.0041
# Epoch 34/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0047 - val_loss: 0.0041
# Epoch 35/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0048 - val_loss: 0.0041
# Epoch 36/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0050 - val_loss: 0.0040
# Epoch 37/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0049 - val_loss: 0.0040
# Epoch 38/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0046 - val_loss: 0.0044
# Epoch 39/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0052 - val_loss: 0.0041
# Epoch 40/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0047 - val_loss: 0.0039
# Epoch 41/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0048 - val_loss: 0.0043
# Epoch 42/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0053 - val_loss: 0.0040
# Epoch 43/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0048 - val_loss: 0.0039
# Epoch 44/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0047 - val_loss: 0.0039
# Epoch 45/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0049 - val_loss: 0.0039
# Epoch 46/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0051 - val_loss: 0.0039
# Epoch 47/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0049 - val_loss: 0.0039
# Epoch 48/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0047 - val_loss: 0.0039
# Epoch 49/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0046 - val_loss: 0.0038
# Epoch 50/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0046 - val_loss: 0.0040
# Epoch 51/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0044 - val_loss: 0.0038
# Epoch 52/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0044 - val_loss: 0.0040
# Epoch 53/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0046 - val_loss: 0.0038
# Epoch 54/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0049 - val_loss: 0.0039
# Epoch 55/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0048 - val_loss: 0.0043
# Epoch 56/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0044 - val_loss: 0.0044
# Epoch 57/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0048 - val_loss: 0.0038
# Epoch 58/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0048 - val_loss: 0.0039
# Epoch 59/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0046 - val_loss: 0.0038
# Epoch 60/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0046 - val_loss: 0.0038
# Epoch 61/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0047 - val_loss: 0.0040
# Epoch 62/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0043 - val_loss: 0.0039
# Epoch 63/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0046 - val_loss: 0.0039
# Epoch 64/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0049 - val_loss: 0.0038
# Epoch 65/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0043 - val_loss: 0.0039
# Epoch 66/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0048 - val_loss: 0.0038
# Epoch 67/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0047 - val_loss: 0.0039
# Epoch 68/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0048 - val_loss: 0.0038
# Epoch 69/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0051 - val_loss: 0.0038
# Epoch 70/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0045 - val_loss: 0.0038
# Epoch 71/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0046 - val_loss: 0.0038
# Epoch 72/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0046 - val_loss: 0.0037
# Epoch 73/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0045 - val_loss: 0.0037
# Epoch 74/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0048 - val_loss: 0.0038
# Epoch 75/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0044 - val_loss: 0.0037
# Epoch 76/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0044 - val_loss: 0.0038
# Epoch 77/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0045 - val_loss: 0.0037
# Epoch 78/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0048 - val_loss: 0.0037
# Epoch 79/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0043 - val_loss: 0.0037
# Epoch 80/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0045 - val_loss: 0.0038
# Epoch 81/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0044 - val_loss: 0.0037
# Epoch 82/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0043 - val_loss: 0.0038
# Epoch 83/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0045 - val_loss: 0.0038
# Epoch 84/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0046 - val_loss: 0.0039
# Epoch 85/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0044 - val_loss: 0.0038
# Epoch 86/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0044 - val_loss: 0.0037
# Epoch 87/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0044 - val_loss: 0.0036
# Epoch 88/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0044 - val_loss: 0.0037
# Epoch 89/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0044 - val_loss: 0.0037
# Epoch 90/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0045 - val_loss: 0.0037
# Epoch 91/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0045 - val_loss: 0.0037
# Epoch 92/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0046 - val_loss: 0.0036
# Epoch 93/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0046 - val_loss: 0.0036
# Epoch 94/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0044 - val_loss: 0.0038
# Epoch 95/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0044 - val_loss: 0.0036
# Epoch 96/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0045 - val_loss: 0.0037
# Epoch 97/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0043 - val_loss: 0.0038
# Epoch 98/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0046 - val_loss: 0.0039
# Epoch 99/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0047 - val_loss: 0.0037
# Epoch 100/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0043 - val_loss: 0.0037

# %% [markdown]
# ## ข้อ 10.

# %%
from sklearn.metrics import mean_squared_error

test_predict = model.predict(testX)

# Reshape testY and test_predict to be 2D arrays
testY_reshaped = testY.reshape(-1, output_length)
test_predict_reshaped = test_predict.reshape(-1, output_length) # test_predict is now already in the correct shape

test_rmse = mean_squared_error(testY_reshaped, test_predict_reshaped)

print('Test RMSE: %.3f RMSE' % (test_rmse))
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Test RMSE: 0.008 RMSE

# %% [markdown]
# ## ข้อ 11.

# %%
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.12/dist-packages (0.2.66)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2.0.2)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2.32.4)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.12/dist-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from yfinance) (4.4.0)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.12/dist-packages (from yfinance) (3.18.2)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.12/dist-packages (from yfinance) (4.13.5)
# Requirement already satisfied: curl_cffi>=0.7 in /usr/local/lib/python3.12/dist-packages (from yfinance) (0.13.0)
# Requirement already satisfied: protobuf>=3.19.0 in /usr/local/lib/python3.12/dist-packages (from yfinance) (5.29.5)
# Requirement already satisfied: websockets>=13.0 in /usr/local/lib/python3.12/dist-packages (from yfinance) (15.0.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Requirement already satisfied: cffi>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from curl_cffi>=0.7->yfinance) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in /usr/local/lib/python3.12/dist-packages (from curl_cffi>=0.7->yfinance) (2025.8.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3.0->yfinance) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->yfinance) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->yfinance) (2.5.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.23)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)

# %% [markdown]
# # Create Sequential dataset for Many to One
# input length = 12
# output length = 1

# %%
def GenXY(dat):
  X, Y = [], []
  for i in range(len(dat) - 12):
    X.append(dat[i : i + 12])
    Y.append(dat[i + 12])
  X = np.array(X)
  Y = np.array(Y)
  return X,Y

# %% [markdown]
# ## ข้อ 12.

# %%
import yfinance as yf
stock = yf.Ticker("PTT.BK")
stock_data = stock.history(period="max")

# %% [markdown]
# ## ข้อ 13.

# %%
data= stock_data['Close']
data
# Out:
# Date
# 2001-12-06 00:00:00+07:00     1.232156
# 2001-12-07 00:00:00+07:00     1.223539
# 2001-12-10 00:00:00+07:00     1.223539
# 2001-12-11 00:00:00+07:00     1.171841
# 2001-12-12 00:00:00+07:00     1.206306
#                                ...
# 2025-10-06 00:00:00+07:00    32.000000
# 2025-10-07 00:00:00+07:00    32.000000
# 2025-10-08 00:00:00+07:00    32.000000
# 2025-10-09 00:00:00+07:00    32.000000
# 2025-10-10 00:00:00+07:00    31.500000
# Name: Close, Length: 5886, dtype: float64

# %%
data = data.reset_index()
data = data.drop(columns=['Date'])
data
# Out:
#           Close
# 0      1.232156
# 1      1.223539
# 2      1.223539
# 3      1.171841
# 4      1.206306
# ...         ...
# 5881  32.000000
# 5882  32.000000
# 5883  32.000000
# 5884  32.000000
# 5885  31.500000
#
# [5886 rows x 1 columns]

# %%
n=int(len(data)*0.8)
n
# Out:
# 4708

# %%
train=data[:n]
test=data[n:]
train.shape
# Out:
# (4708, 1)

# %%
test.shape
# Out:
# (1178, 1)

# %%
def GenXY(dat):
  X, Y = [], []
  for i in range(len(dat) - 7):
    X.append(dat[i : i + 7])
    Y.append(dat[i + 7])
  X = np.array(X)
  Y = np.array(Y)
  return X,Y

# %%
xTrain,yTrain=GenXY(train.values)
xTest,yTest=GenXY(test.values)

# %%
from tensorflow.keras.layers import Input, GRU, Dense
from tensorflow.keras.models import Sequential
model = Sequential([
  Input(shape=(7, 1)),
  GRU(60, activation = 'tanh'),
  Dense(1, activation = 'sigmoid')
  ])
model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(xTrain, yTrain, epochs=100)
# Out:
# Epoch 1/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 8s 29ms/step - loss: 317.1927
# Epoch 2/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 331.5202
# Epoch 3/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 319.6504
# Epoch 4/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - loss: 317.2948
# Epoch 5/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - loss: 316.3535
# Epoch 6/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - loss: 329.2053
# Epoch 7/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 324.4692
# Epoch 8/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 315.5547
# Epoch 9/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 321.7705
# Epoch 10/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 310.5888
# Epoch 11/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 314.3700
# Epoch 12/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 320.4294
# Epoch 13/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 326.3798
# Epoch 14/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 324.0334
# Epoch 15/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 323.8314
# Epoch 16/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 320.4598
# Epoch 17/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 316.6821
# Epoch 18/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 320.9810
# Epoch 19/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 320.6702
# Epoch 20/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 309.4631
# Epoch 21/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 325.4077
# Epoch 22/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 326.3272
# Epoch 23/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 319.2614
# Epoch 24/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 316.5831
# Epoch 25/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 321.8598
# Epoch 26/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 321.8676
# Epoch 27/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 318.0221
# Epoch 28/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 317.0031
# Epoch 29/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 318.1635
# Epoch 30/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 311.7117
# Epoch 31/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 322.6332
# Epoch 32/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 318.4816
# Epoch 33/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 313.0095
# Epoch 34/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 315.5636
# Epoch 35/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 316.3405
# Epoch 36/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 326.6412
# Epoch 37/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 315.4503
# Epoch 38/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 316.6734
# Epoch 39/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 316.2319
# Epoch 40/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 321.2196
# Epoch 41/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 322.2279
# Epoch 42/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 323.9531
# Epoch 43/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 322.9547
# Epoch 44/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 323.9405
# Epoch 45/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 324.2453
# Epoch 46/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 317.1806
# Epoch 47/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 316.6109
# Epoch 48/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 319.6774
# Epoch 49/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 318.2281
# Epoch 50/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 316.3824
# Epoch 51/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 321.6083
# Epoch 52/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 324.7995
# Epoch 53/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 320.6603
# Epoch 54/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 320.6760
# Epoch 55/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 309.5063
# Epoch 56/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 325.3336
# Epoch 57/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 321.8311
# Epoch 58/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 328.1872
# Epoch 59/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 325.1507
# Epoch 60/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 312.7924
# Epoch 61/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 321.0860
# Epoch 62/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 319.4429
# Epoch 63/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 317.6796
# Epoch 64/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 314.5880
# Epoch 65/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - loss: 329.3546
# Epoch 66/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 313.0016
# Epoch 67/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 323.5896
# Epoch 68/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 314.1076
# Epoch 69/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 321.7899
# Epoch 70/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 326.5464
# Epoch 71/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 314.4226
# Epoch 72/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 325.0261
# Epoch 73/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 316.0408
# Epoch 74/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 314.6178
# Epoch 75/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 312.7921
# Epoch 76/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 316.7357
# Epoch 77/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 316.8831
# Epoch 78/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 319.3545
# Epoch 79/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 315.8582
# Epoch 80/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 324.7061
# Epoch 81/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 320.8179
# Epoch 82/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 308.8458
# Epoch 83/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 319.0589
# Epoch 84/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 315.6590
# Epoch 85/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 325.2792
# Epoch 86/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 317.5264
# Epoch 87/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 312.7966
# Epoch 88/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 326.4162
# Epoch 89/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 322.6077
# Epoch 90/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 322.2817
# Epoch 91/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 317.4481
# Epoch 92/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 321.1198
# Epoch 93/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 315.8970
# Epoch 94/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 316.6706
# Epoch 95/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 327.5443
# Epoch 96/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 321.1717
# Epoch 97/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 327.7979
# Epoch 98/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 319.2512
# Epoch 99/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 320.3257
# Epoch 100/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 314.3310

# %% [markdown]
# ## ข้อ 14.

# %%
from sklearn.metrics import r2_score

predictions = model.predict(xTest)
r2 = r2_score(yTest, predictions)
print(f"R square (r2): {r2}")
# Out:
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
# R square (r2): -354.0996517574837

# %%
import matplotlib.pyplot as plt
plt.plot(yTest, label='Actual Close Price')
plt.plot(predictions, label='Predicted Close Price')
plt.legend()
plt.xlabel('Time')
plt.ylabel('Price')
plt.title('Actual vs Predicted Close Price')
plt.show()

# %% [markdown]
# ## ข้อ 15.

# %%
def GenXY(dat, timstep):
  X, Y = [], []
  for i in range(len(dat) - time_steps - output_length + 1):
    X.append(dat[i : i + time_steps])
    Y.append(dat[i+ time_steps : i + time_steps +output_length])
  X = np.array(X)
  Y = np.array(Y)
  return X,Y

time_steps = 30
output_length = 5
trainX, trainY = GenXY(train, time_steps)
testX, testY = GenXY(test, time_steps)

# %% [markdown]
# ## ข้อ 16.

# %%
pip install scikeras
# Out:
# Requirement already satisfied: scikeras in /usr/local/lib/python3.12/dist-packages (0.13.0)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.12/dist-packages (from scikeras) (3.10.0)
# Requirement already satisfied: scikit-learn>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from scikeras) (1.7.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (2.0.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (0.1.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (3.14.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (0.17.0)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (0.5.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (25.0)
# Requirement already satisfied: scipy>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.16.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.4.2->scikeras) (3.6.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from optree->keras>=3.2.0->scikeras) (4.15.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.2.0->scikeras) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.2.0->scikeras) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->scikeras) (0.1.2)

# %%
pip install --upgrade scikit-learn scikeras
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.7.2)
# Requirement already satisfied: scikeras in /usr/local/lib/python3.12/dist-packages (0.13.0)
# Requirement already satisfied: numpy>=1.22.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.12/dist-packages (from scikeras) (3.10.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (1.4.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (0.1.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (3.14.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (0.17.0)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (0.5.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (25.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from optree->keras>=3.2.0->scikeras) (4.15.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.2.0->scikeras) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.2.0->scikeras) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->scikeras) (0.1.2)

# %%
from sklearn.model_selection import GridSearchCV
from scikeras.wrappers import KerasRegressor

param_grid = {
    'model__hidden_units': [10, 20, 30, 50, 100]
}

# %%
def create_model(hidden_units=50):
    model = Sequential([
        Input(shape=(7, 1)),
        GRU(hidden_units, activation='tanh'),
        Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer='adam', loss='mse', metrics=['mae'])
    return model

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense, Input
from scikeras.wrappers import KerasRegressor
from sklearn.model_selection import GridSearchCV

def create_model(hidden_units=50):
    model = Sequential([
        Input(shape=(7, 1)),
        GRU(hidden_units, activation='tanh'),
        Dense(1, activation='linear')
    ])
    model.compile(optimizer='adam', loss='mse', metrics=['mae'])
    return model

trainX = np.random.rand(200, 7, 1)
trainY = np.random.rand(200)

model = KerasRegressor(
    model=create_model,
    epochs=20,
    batch_size=16,
    verbose=0,
    X_shape_=(7, 1)
)

param_grid = {
    'model__hidden_units': [10, 20, 30, 50, 100]
}

grid = GridSearchCV(estimator=model, param_grid=param_grid, cv=3, n_jobs=-1)
grid_result = grid.fit(trainX, trainY)

print("Best hidden_units:", grid_result.best_params_['model__hidden_units'])
print("Best score:", grid_result.best_score_)
# Out:
# Best hidden_units: 30
# Best score: -0.048147437988205866
