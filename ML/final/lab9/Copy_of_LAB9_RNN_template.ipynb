# %% [markdown]
# ## ข้อ 1.

# %%
import pandas as pd
import numpy as np

url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/monthly-sunspots.csv"
df = pd.read_csv(url)

data = df.values

print(len(data))
# Out:
# 2820

# %% [markdown]
# ## ข้อ 2.

# %%
data
# Out:
# array([['1749-01', 58.0],
#        ['1749-02', 62.6],
#        ['1749-03', 70.0],
#        ...,
#        ['1983-10', 55.8],
#        ['1983-11', 33.3],
#        ['1983-12', 33.4]], dtype=object)

# %%
import matplotlib.pyplot as plt

#### Plot graph
plt.figure(figsize=(15, 6), dpi=80)
plt.plot(df['Sunspots'])

# %% [markdown]
# ## ข้อ 3.

# %%
df=df.drop(columns=['Sunspots'])
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2231790583.py in <cell line: 0>()
# ----> 1 df=df.drop(columns=['Sunspots'])
#       2 df
#
# AttributeError: 'numpy.ndarray' object has no attribute 'drop'

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))
df = scaler.fit_transform(df.values.reshape(-1, 1))
df
# Out:
# array([[0.2285264 ],
#        [0.24665091],
#        [0.27580772],
#        ...,
#        [0.21985816],
#        [0.13120567],
#        [0.13159968]])

# %%
from sklearn.model_selection import train_test_split
train_data, test_data = train_test_split(data, train_size=0.8, shuffle=False)

# %%
train_data
# Out:
# array([['1749-01', 58.0],
#        ['1749-02', 62.6],
#        ['1749-03', 70.0],
#        ...,
#        ['1936-10', 89.0],
#        ['1936-11', 115.4],
#        ['1936-12', 123.4]], dtype=object)

# %%
test_data
# Out:
# array([['1937-01', 132.5],
#        ['1937-02', 128.5],
#        ['1937-03', 83.9],
#        ...,
#        ['1983-10', 55.8],
#        ['1983-11', 33.3],
#        ['1983-12', 33.4]], dtype=object)

# %% [markdown]
# ## ข้อ 4.

# %%
def GenXY(dat, timstep):          ## receive sequence data and timesteps




    return X,Y

time_steps = 12                             ## number time_steps
trainX, trainY = gen_XY(train_data, time_steps)
testX, testY = gen_XY(test_data, time_steps)

# %% [markdown]
# ## ข้อ 5.

# %%
from tensorflow.keras.layers import Input, SimpleRNN, Dense

model = Sequential([


    ])

model.summary()
model.compile(loss='....', optimizer='.....')

hist = model.fit(trainX, trainY, epochs=50, validatation_split = )

# %% [markdown]
# ## ข้อ 6.

# %%
from sklearn.metrics import mean_squared_error

test_predict = model.predict(...........)


test_rmse = mean_squared_error(........ , test_predict)

print('Test RMSE: %.3f RMSE' % (test_rmse))

# %% [markdown]
# ## ข้อ 7.

# %% [markdown]
# ## ข้อ 8.

# %% [markdown]
# ## ข้อ 9.

# %%
from tensorflow.keras.layers import Input, LSTM, Dense

# %% [markdown]
# ## ข้อ 10.

# %% [markdown]
# ## ข้อ 11.

# %%
# !pip install yfinance

# %% [markdown]
# # Create Sequential dataset for Many to One
# input length = 12
# output length = 1

# %% [markdown]
# ## ข้อ 12.

# %% [markdown]
# ## ข้อ 13.

# %%
from tensorflow.keras.layers import Input, GRU, Dense

# %% [markdown]
# ## ข้อ 14.

# %%
from sklearn.metrics import r2_score

# %% [markdown]
# ## ข้อ 15.

# %% [markdown]
# ## ข้อ 16.

# %%
from sklearn.model_selection import GridSearchCV
