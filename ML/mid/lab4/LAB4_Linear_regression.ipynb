# %% [markdown]
# ## Auto-MPG
#
# ![](https://factsanddetails.com/media/2/20111201-Molycorp%20REs-hev.png)
#
# ###The data is technical spec of cars, aiming to predict city fuel consumption
# ### (mile-per-gallon: MPG).
#
# The features consist of
# *   cylinders
# *   displacement
# *   horsepower
# *   weight
# *   acceleration
# *   model year
# *   original
# *   car name
#
# The output
# mpg mile-per-gallon
#
# [source] https://gist.githubusercontent.com/omarish/5687264/raw/7e5c814ce6ef33e25d5259c1fe79463c190800d9/mpg.csv

# %% [markdown]
# ## ข้อ 1

# %%
import pandas as pd
df=pd.read_csv('Auto-MPG.csv')

# %% [markdown]
# ## ข้อ 2

# %%
temp=df['horsepower'].mode()[0]
df['horsepower'] = df['horsepower'].replace('?', temp)

# %% [markdown]
# ## ข้อ 3

# %%
temp=df['name']
for i in range(398):
    temp2=temp[i].split()
    df.at[i, 'name']=temp2[0]
df['name']=df['name'].replace({'chevy': 'chevrolet', 'vw': 'volkswagen'})
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin        name
# 0            70       1   chevrolet
# 1            70       1       buick
# 2            70       1    plymouth
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df['name']=label_encoder.fit_transform(df['name'])
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin  name
# 0            70       1     7
# 1            70       1     3
# 2            70       1    24
# ...

# %% [markdown]
# ## ข้อ 4

# %%
y=df['mpg']
x=df.drop(columns=['mpg'])

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(-1,1))
x=pd.DataFrame(scaler.fit_transform(x), columns=x.columns)
x
# Out:
#      cylinders  displacement  horsepower    weight  acceleration  model_year  \
# 0          1.0      0.235142   -0.086957  0.072299     -0.523810        -1.0
# 1          1.0      0.457364    0.293478  0.179473     -0.583333        -1.0
# 2          1.0      0.291990    0.130435  0.033740     -0.642857        -1.0
# 3          1.0      0.219638    0.130435  0.032039     -0.523810        -1.0
# 4          1.0      0.209302    0.021739  0.041111     -0.702381        -1.0
# ..         ...           ...         ...       ...           ...         ...
# 393       -0.6     -0.627907   -0.565217 -0.332577     -0.095238         1.0
# 394       -0.6     -0.850129   -0.934783 -0.706833      0.976190         1.0
# 395       -0.6     -0.653747   -0.586957 -0.613269     -0.571429         1.0
# 396       -0.6     -0.731266   -0.641304 -0.426141      0.261905         1.0
# 397       -0.6     -0.736434   -0.608696 -0.372271      0.357143         1.0
#
#      origin      name
# ...

# %%
from sklearn.model_selection import train_test_split
xTrain,xTest,yTrain,yTest=train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# ## ข้อ 5

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(xTrain,yTrain)
# Out:
# LinearRegression()

# %%
print('w1: ',model.coef_)
print('w0: ',model.intercept_)
# Out:
# w1:  [ -0.28571781   2.58104234  -0.44459705 -12.28268477   0.85376031
#    4.81942969   1.09745821   0.84399698]
# w0:  22.082310633617663

# %%
y_pred =model.predict(xTest)
y_pred
# Out:
# array([32.45547859, 29.58293339, 20.68356995, 17.49231966, 13.146145  ,
#        27.68233754, 27.89169303,  9.840724  , 17.31998207, 21.74857969,
#        12.39759565, 35.77927963, 25.85937239, 13.16427008, 23.61036707,
#         6.26090497, 30.19695348, 24.58722347, 17.13037722, 36.10317522,
#        24.45145086, 19.51057401, 28.8297931 , 28.7109642 , 14.69356991,
#        35.60414288, 25.24729286, 25.51693048, 21.365034  ,  8.69917759,
#        28.36174904, 35.70404344, 20.16222839, 26.52053025, 33.63372644,
#        13.1092073 , 23.40238738, 21.69250668, 12.93477029, 26.00991608,
#        26.82273723, 28.22231206, 21.03218371,  7.70320716, 24.96423688,
#        34.95351588, 26.34299356, 24.80305075, 23.1249296 , 28.32527593,
#        22.35172917, 33.31286137, 32.30172806, 10.95723707, 27.55370522,
#        10.67631849, 19.64758302, 30.23489028, 22.91196175, 20.93583759,
#        16.91424751, 31.66240412, 23.94757924, 20.7813468 , 21.47659665,
# ...

# %% [markdown]
# ## ข้อ 6

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error
print("MAE: ",mean_absolute_error(yTest,y_pred))
print("MSE: ",mean_squared_error(yTest,y_pred))
# Out:
# MAE:  2.2956399270727283
# MSE:  8.333278278541442

# %% [markdown]
# ## ข้อ 7
# ### อับโหลดข้อมูลจ 'transactions.csv' จาก google classroom

# %%
df=pd.read_csv('transactions.csv')
df
# Out:
#          Date    P1    P2    P3
# 0    1/1/2022   6.0  15.0  31.0
# 1    2/1/2022  19.0   0.0  30.0
# 2    3/1/2022  14.0  20.0   6.0
# 3    4/1/2022  10.0  21.0  17.0
# 4    5/1/2022   7.0  20.0  33.0
# ..        ...   ...   ...   ...
# 766       NaN   NaN   NaN   NaN
# 767       NaN   NaN   NaN   NaN
# 768       NaN   NaN   NaN   NaN
# 769       NaN   NaN   NaN   NaN
# 770       NaN   NaN   NaN   NaN
#
# [771 rows x 4 columns]

# %%
df=df.dropna()
df
# Out:
#            Date    P1    P2    P3
# 0      1/1/2022   6.0  15.0  31.0
# 1      2/1/2022  19.0   0.0  30.0
# 2      3/1/2022  14.0  20.0   6.0
# 3      4/1/2022  10.0  21.0  17.0
# 4      5/1/2022   7.0  20.0  33.0
# ..          ...   ...   ...   ...
# 725  27/12/2023  16.0  21.0  35.0
# 726  28/12/2023   3.0   4.0  17.0
# 727  29/12/2023   0.0  12.0  31.0
# 728  30/12/2023   7.0  28.0  19.0
# 729  31/12/2023  16.0  17.0  29.0
#
# [730 rows x 4 columns]

# %% [markdown]
# ## ข้อ 8

# %%
print(df['P1'].mean())
print(df['P3'].mean())
# Out:
# 9.23013698630137
# 27.44931506849315

# %% [markdown]
# ## ข้อ 9

# %%
df
# Out:
#            Date    P1    P2    P3
# 0      1/1/2022   6.0  15.0  31.0
# 1      2/1/2022  19.0   0.0  30.0
# 2      3/1/2022  14.0  20.0   6.0
# 3      4/1/2022  10.0  21.0  17.0
# 4      5/1/2022   7.0  20.0  33.0
# ..          ...   ...   ...   ...
# 725  27/12/2023  16.0  21.0  35.0
# 726  28/12/2023   3.0   4.0  17.0
# 727  29/12/2023   0.0  12.0  31.0
# 728  30/12/2023   7.0  28.0  19.0
# 729  31/12/2023  16.0  17.0  29.0
#
# [730 rows x 4 columns]

# %%
#df[['Day', 'Month', 'Year']] = df['Date'].str.split('/', expand=True)
#df[['Day', 'Month', 'Year']]=df[['Day', 'Month', 'Year']].astype(int)

df=df.drop(columns=['Date'])

# %%
df.dtypes
# Out:
# P1    float64
# P2    float64
# P3    float64
# dtype: object

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df=pd.DataFrame(scaler.fit_transform(df), columns=df.columns)

# %%
y=df['P1']
x=df.drop(columns=['P1'])
#x=df.drop(columns=['Date','P1'])

xTrain=x[:700]
yTrain=y[:700]

xTest=x[700:]
yTest=y[700:]

# %% [markdown]
# ## ข้อ 10

# %%
model=LinearRegression()
model.fit(xTrain,yTrain)
# Out:
# LinearRegression()

# %%
y_pred =model.predict(xTest)
y_pred

print("MAE:",mean_absolute_error(yTest,y_pred))
# Out:
# MAE: 0.8771898679054532

# %% [markdown]
# ## ข้อ 11

# %%
df=pd.read_csv('transactions.csv')
df=df.dropna()

# %%
df
# Out:
#            Date    P1    P2    P3
# 0      1/1/2022   6.0  15.0  31.0
# 1      2/1/2022  19.0   0.0  30.0
# 2      3/1/2022  14.0  20.0   6.0
# 3      4/1/2022  10.0  21.0  17.0
# 4      5/1/2022   7.0  20.0  33.0
# ..          ...   ...   ...   ...
# 725  27/12/2023  16.0  21.0  35.0
# 726  28/12/2023   3.0   4.0  17.0
# 727  29/12/2023   0.0  12.0  31.0
# 728  30/12/2023   7.0  28.0  19.0
# 729  31/12/2023  16.0  17.0  29.0
#
# [730 rows x 4 columns]

# %%
df
# Out:
#            Date    P1    P2    P3
# 0      1/1/2022   6.0  15.0  31.0
# 1      2/1/2022  19.0   0.0  30.0
# 2      3/1/2022  14.0  20.0   6.0
# 3      4/1/2022  10.0  21.0  17.0
# 4      5/1/2022   7.0  20.0  33.0
# ..          ...   ...   ...   ...
# 725  27/12/2023  16.0  21.0  35.0
# 726  28/12/2023   3.0   4.0  17.0
# 727  29/12/2023   0.0  12.0  31.0
# 728  30/12/2023   7.0  28.0  19.0
# 729  31/12/2023  16.0  17.0  29.0
#
# [730 rows x 4 columns]

# %%
newdf=[]
size=len(df)

# %%
for i in range (0,size,7):
    a=0
    b=0
    c=0
    aa=0
    bb=0
    cc=0
    ab=0
    bc=0
    ac=0
    if(i+7<size):
        for j in range(7):
            a+=df.at[i+j, 'P1']
            b+=df.at[i+j, 'P2']
            c+=df.at[i+j, 'P3']
            
            aa+=df.at[i+j, 'P1']*df.at[i+j, 'P1']
            bb+=df.at[i+j, 'P2']*df.at[i+j, 'P2']
            cc+=df.at[i+j, 'P3']*df.at[i+j, 'P3']
            
            ab+=df.at[i+j, 'P1']+df.at[i+j, 'P2']
            bc+=df.at[i+j, 'P2']+df.at[i+j, 'P3']
            ac+=df.at[i+j, 'P1']+df.at[i+j, 'P3']
        newdf.append([i/7,a/7,b/7,c/7,aa/7,bb/7,cc/7,ab/7,bc/7,ac/7])
    else:
        for j in range(i, size):
            a+=df.at[j, 'P1']
            b+=df.at[j, 'P2']
            c+=df.at[j, 'P3']
            
            aa+=df.at[j, 'P1']*df.at[j, 'P1']
            bb+=df.at[j, 'P2']*df.at[j, 'P2']
            cc+=df.at[j, 'P3']*df.at[j, 'P3']
            
            ab+=df.at[j, 'P1']+df.at[j, 'P2']
            bc+=df.at[j, 'P2']+df.at[j, 'P3']
            ac+=df.at[j, 'P1']+df.at[j, 'P3']
        remain=size-i
        newdf.append([remain,a/remain,b/remain,c/remain,aa/remain,bb/remain,cc/remain,ab/remain,bc/remain,ac/remain])

# %%
df = pd.DataFrame(newdf, columns=['week','P1', 'P2', 'P3','P11','P22','P33','P12','P23','P13'])
df
# Out:
#       week         P1         P2         P3         P11          P22  \
# 0      0.0  11.428571  30.142857  26.857143  157.428571  2155.857143
# 1      1.0   6.285714  12.571429  24.857143   54.857143   209.428571
# 2      2.0   7.571429  16.571429  29.285714   86.428571   308.285714
# 3      3.0  13.285714  17.428571  31.142857  203.857143   311.142857
# 4      4.0   8.857143  11.571429  30.142857  110.571429   167.000000
# ..     ...        ...        ...        ...         ...          ...
# 100  100.0   9.571429  15.428571  37.571429  143.285714   290.000000
# 101  101.0   6.714286  16.714286  25.142857   70.142857   393.000000
# 102  102.0  10.571429  16.285714  26.571429  132.000000   334.285714
# 103  103.0  10.285714   9.285714  29.714286  140.285714   124.428571
# 104    2.0  11.500000  22.500000  24.000000  152.500000   536.500000
#
#              P33        P12        P23        P13
# 0     872.571429  41.571429  57.000000  38.285714
# ...

# %%
cor=df.corr()['P2']
cor
# Out:
# week   -0.129533
# P1     -0.052514
# P2      1.000000
# P3     -0.026963
# P11    -0.054125
# P22     0.790356
# P33     0.004927
# P12     0.824581
# P23     0.576789
# P13    -0.045734
# Name: P2, dtype: float64

# %%
y=df['P2']
x=df[['week','P13','P12','P33']]

scaler = StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x), columns=x.columns)

# %%
xTrain=x[:101]
yTrain=y[:101]

xTest=x[101:]
yTest=y[101:]

# %%
model=LinearRegression()
model.fit(xTrain,yTrain)
# Out:
# LinearRegression()

# %% [markdown]
# ## ข้อ 12

# %%
result=model.score(xTest,yTest)
print("accuracy: {:.2f}%".format(result*100))
# Out:
# accuracy: 93.89%

# %% [markdown]
# ## ข้อ 13

# %%
print('w1: ',model.coef_)
print('w0: ',model.intercept_)
# Out:
# w1:  [-0.18518701 -4.26557016  3.58955467  3.62028759]
# w0:  16.56351040158628

# %%
xTest
# Out:
#          week       P13       P12       P33
# 101  1.651301 -0.897993 -0.598231 -0.166436
# 102  1.684346  0.087934  0.257355  0.005505
# 103  1.717390  0.620868 -1.560764  0.081202
# 104 -1.620144 -0.218503  2.039824 -1.253769

# %%
y_pred =model.predict(xTest)
y_pred
# Out:
# array([17.33823732, 16.82022012,  8.28864172, 20.57863586])

# %%
yTest
# Out:
# 101    16.714286
# 102    16.285714
# 103     9.285714
# 104    22.500000
# Name: P2, dtype: float64
